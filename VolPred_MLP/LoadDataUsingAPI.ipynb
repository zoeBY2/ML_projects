# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/ML/Kaggle_Janestreet/Data/"


# %cd /content/drive/MyDrive/ML/Kaggle_Janestreet/Data
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ML/Kaggle_Janestreet/Data

# %%
# !kaggle datasets download -d pedrocouto39/jane-street-market-train-data-best-formats
# Out:
# ...
# 100% 10.3G/10.3G [02:19<00:00, 74.9MB/s]
# 100% 10.3G/10.3G [02:19<00:00, 79.2MB/s]

# %%
import zipfile
for file in os.listdir():
    if file.endswith(".zip"):
        with zipfile.ZipFile(file, "r") as zip_file:
            zip_file.extractall()
        # os.remove(file)
