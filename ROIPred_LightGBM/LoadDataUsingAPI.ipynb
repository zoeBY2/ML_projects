# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/ML/Kaggle_Ubiquant/Data"


# %cd /content/drive/MyDrive/ML/Kaggle_Ubiquant/Data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ML/Kaggle_Ubiquant/Data

# %%
# !kaggle competitions download -c ubiquant-market-prediction
# Out:
# 403 - Forbidden

# %%
# !kaggle datasets download -d robikscube/ubiquant-parquet
# Out:
# ...
# 100% 12.5G/12.5G [02:40<00:00, 74.9MB/s]
# 100% 12.5G/12.5G [02:40<00:00, 83.6MB/s]

# %%
import zipfile
for file in os.listdir():
    if file.endswith(".zip"):
        with zipfile.ZipFile(file, "r") as zip_file:
            zip_file.extractall()
        # os.remove(file)
