# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/ML/Kaggle_Ubiquant/"
# %cd /content/drive/MyDrive/ML/Kaggle_Ubiquant/

# %run ./Notebook/Functions.ipynb
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ML/Kaggle_Ubiquant

# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=256387 sha256=d2c97cd4882e65bd4bf41350409beb2f18f3f656e9b02c3c03374875b0a47772
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...

# %%
# import pyarrow.parquet as pq

# # Specify the path to the Parquet file
# parquet_file = './Data/train.parquet'

# # Load the Parquet file
# table = pq.read_table(parquet_file)

# # Convert the table to a Pandas DataFrame
# data = table.to_pandas()

# display(data.head(2))

# %%
import pickle5 as pickle

data = pickle.load(open('./Data/train_compressed.pkl', 'rb'))
# data = pickle.load(open('./Data/train.parquet', 'rb'))
len(data['investment_id'].unique())
# Out:
# 2788

# %%
data.head(2)
# Out:
#   row_id  time_id  investment_id    target       f_0       f_1       f_2  \
# 0    0_1      0.0            1.0 -0.300781  0.932617  0.113708 -0.402100
# 1    0_2      0.0            2.0 -0.231079  0.811035 -0.514160  0.742188
#
#         f_3       f_4       f_5       f_6       f_7       f_8       f_9  \
# 0  0.378418 -0.203979 -0.413574  0.965820  1.230469  0.114807 -2.013672
# 1 -0.616699 -0.194214  1.771484  1.427734  1.133789  0.114807 -0.219238
#
#        f_10     f_11      f_12      f_13      f_14      f_15      f_16  \
# 0  0.004936  0.28418  0.501953 -0.287842 -1.168945 -0.267334 -0.574219
# 1 -0.351807  0.84668  0.440186  0.499756  0.893066 -0.010216 -0.681641
#
#        f_17      f_18      f_19      f_20      f_21      f_22      f_23  \
# 0 -0.771973  1.012695 -1.230469  1.786133 -2.089844  0.325684 -0.877930
# 1  1.253906 -1.027344 -1.690430  0.011154  0.875488  0.325684 -0.458252
#
#        f_24      f_25      f_26      f_27      f_28      f_29      f_30  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141410 entries, 0 to 3141409
# Columns: 304 entries, row_id to f_299
# dtypes: category(1), float16(303)
# memory usage: 1.8 GB

# %%
##### No missing values observed.

missingvalues = data.loc[data.isnull().all(1)].reset_index(drop=True)
missingvalues
# Out:
# Empty DataFrame
# Columns: [row_id, time_id, investment_id, target, f_0, f_1, f_2, f_3, f_4, f_5, f_6, f_7, f_8, f_9, f_10, f_11, f_12, f_13, f_14, f_15, f_16, f_17, f_18, f_19, f_20, f_21, f_22, f_23, f_24, f_25, f_26, f_27, f_28, f_29, f_30, f_31, f_32, f_33, f_34, f_35, f_36, f_37, f_38, f_39, f_40, f_41, f_42, f_43, f_44, f_45, f_46, f_47, f_48, f_49, f_50, f_51, f_52, f_53, f_54, f_55, f_56, f_57, f_58, f_59, f_60, f_61, f_62, f_63, f_64, f_65, f_66, f_67, f_68, f_69, f_70, f_71, f_72, f_73, f_74, f_75, f_76, f_77, f_78, f_79, f_80, f_81, f_82, f_83, f_84, f_85, f_86, f_87, f_88, f_89, f_90, f_91, f_92, f_93, f_94, f_95, ...]
# Index: []

# %%
##### No duplicated rows observed - duplicated group & name observed 
display('Number of records included: '+str(data.shape[0]))
data = data.drop_duplicates()
display('Number of records included after drop duplicates: '+str(data.shape[0]))
#display(data.nunique())
# Out:
# 'Number of records included: 3141410'
# 'Number of records included after drop duplicates: 3141410'

# %%
len(data['time_id'].unique())
# Out:
# 1211

# %%
visualize_target(data, 'target')
# Out:
# target
# ------
# Mean: -0.0211  -  Median: -0.0972  -  Std: 0.0000
# Min: -9.4219  -  25%: -0.5005  -  50%: -0.0972  -  75%: 0.3572  -  Max: 12.0391
# Skew: 0.9443  -  Kurtosis: 6.2083
# Missing Values: 0/3141410 (0.0000%)

# %%
# tmp = data.dropna(subset=['target'])
#data.loc[(data.target==-np.inf) | (data.target==np.inf) | (data.target.isnull())]
# tmp.shape
# Out:
# (3141410, 304)

# %%
df = data.groupby('time_id')['target'].count().reset_index().rename(columns={'target': 'sample counts'})
visualize_time(df, 'sample counts')
# Out:
# sample counts
# -------------
# Mean: 2594.0628  -  Median: 2489.0000  -  Std: 475.5527
# Min: 512.0000  -  25%: 2252.0000  -  50%: 2489.0000  -  75%: 3030.0000  -  Max: 3445.0000
# Skew: -0.4783  -  Kurtosis: 1.2167
# Missing Values: 0/1211 (0.0000%)

# %%
factors = [f"f_{i}" for i in range(300)] 
col_names = factors + ["target"] 

sns.heatmap(data[col_names].corr('kendall'), annot=True)
plt.show()
